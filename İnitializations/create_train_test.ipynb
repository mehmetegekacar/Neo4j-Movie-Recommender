# %%
import pandas as pd
import numpy as np

# %%
ratings_selected = pd.read_csv('data\\ratings_selected.csv')
ratings_selected
# Out:
#        userId  movieId  rating   timestamp             movieTitle
# 0           1        1       1   964982703              Toy Story
# 1           1        3       1   964981247       Grumpier Old Men
# 2           1        6       1   964982224                   Heat
# 3           1       70       1   964982400    From Dusk Till Dawn
# 4           1      101       1   964980868          Bottle Rocket
# ...       ...      ...     ...         ...                    ...
# 49028     610   152372       1  1493848841             Southbound
# 49029     610   156726       1  1493848444                   Hush
# 49030     610   160080       1  1493848031           Ghostbusters
# 49031     610   160571       1  1493848537             Lights Out
# 49032     610   162350       1  1493849971  The Magnificent Seven
#
# [49033 rows x 5 columns]

# %%
ratings_selected.sort_values(by="timestamp", inplace=True, ascending=True)

# %%
user_ids = ratings_selected["userId"].unique()

# %%
empty_df_train = pd.DataFrame(columns=["userId", "movieId", "rating", "timestamp"])
empty_df_test = pd.DataFrame(columns=["userId", "movieId", "rating", "timestamp"])

for i in user_ids:
    df = ratings_selected[ratings_selected["userId"] == i]
    df.sort_values(by="timestamp", inplace=True, ascending=True)
    df_train = df[:int(len(df)*0.8)]
    df_test = df[int(len(df)*0.8):]
    empty_df_train = pd.concat([empty_df_train, df_train])
    empty_df_test = pd.concat([empty_df_test, df_test])
# Out:
# C:\Users\mehme\AppData\Local\Temp\ipykernel_20528\1708322323.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by="timestamp", inplace=True, ascending=True)
# C:\Users\mehme\AppData\Local\Temp\ipykernel_20528\1708322323.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by="timestamp", inplace=True, ascending=True)
# C:\Users\mehme\AppData\Local\Temp\ipykernel_20528\1708322323.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
empty_df_train.to_csv("data\\ratings_train.csv", index=False)

# %%
empty_df_test.to_csv("data\\ratings_test.csv", index=False)
